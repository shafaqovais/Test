# %% [markdown]
# <a href="https://colab.research.google.com/github/shafaqovais/Test/blob/main/09_mar_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas

# %%
import pandas as pd
s1 = pd.Series([1, 2, 3, 4]) 
s2=pd.Series([1, 2, 3, 4], index=['A', 'B', 'C', 'D'])

# %%
df = pd.DataFrame({'foo':['x', 'y', 'z'],
                   'bar':[6, 100, None],
                   'baz':[True, True, False]})

# %%
df.loc[0]
# Out:
# foo       x
# bar     6.0
# baz    True
# Name: 0, dtype: object

# %%
df.loc[0:2]
# Out:
#   foo    bar    baz
# 0   x    6.0   True
# 1   y  100.0   True
# 2   z    NaN  False

# %%
df.iloc[-1]
# Out:
# foo        z
# bar      NaN
# baz    False
# Name: 2, dtype: object

# %%
df.iloc[1]
# Out:
# foo        y
# bar    100.0
# baz     True
# Name: 1, dtype: object

# %%
df[['foo', 'bar']]
# Out:
#   foo    bar
# 0   x    6.0
# 1   y  100.0
# 2   z    NaN

# %%
import pandas as pd
df=pd.DataFrame({
    'Name':['Alice', 'Bob', 'Charlie', 'David', 'Emma'],
    'Age':[25, 30, 35, 27,34],
    'City':['New york','Paris','London','Tokyo','Sydeny'],
    'Salary':[500000,80000,40000,90000,50000]
})

# %%
df[df['Age']>=27]
# Out:
#       Name  Age    City  Salary
# 1      Bob   30   Paris   80000
# 2  Charlie   35  London   40000
# 3    David   27   Tokyo   90000
# 4     Emma   34  Sydeny   50000

# %%
df[(df['Age']<30)&(df['Salary']<=90000)]
# Out:
#     Name  Age   City  Salary
# 3  David   27  Tokyo   90000

# %%
df[(df['Age']<=30)&(df['Salary']<=90000)]
# Out:
#     Name  Age   City  Salary
# 1    Bob   30  Paris   80000
# 3  David   27  Tokyo   90000

# %%
df.query("Age<=30 and Salary <=90000")
# Out:
#     Name  Age   City  Salary
# 1    Bob   30  Paris   80000
# 3  David   27  Tokyo   90000

# %%
a=30
place='New york'
df.query(" Age< @a and City== @place ")
# Out:
#     Name  Age      City  Salary
# 0  Alice   25  New york  500000

# %%
df.value_counts(['Name'])
# Out:
# Name
# Alice      1
# Bob        1
# Charlie    1
# David      1
# Emma       1
# dtype: int64

# %%
df = pd.read_csv("zomato.csv" ,encoding='Latin-1')

# %%
df.value_counts(['Restaurant ID'])
# Out:
# Restaurant ID
# 53               1
# 18264992         1
# 18264995         1
# 18264996         1
# 18264997         1
#                 ..
# 307785           1
# 307786           1
# 307799           1
# 307801           1
# 18500652         1
# Length: 9551, dtype: int64

# %%
df.value_counts()
# Out:
# Restaurant ID  Restaurant Name     Country Code  City       Address                                                              Locality                   Locality Verbose                      Longitude  Latitude   Cuisines                                  Average Cost for two  Currency            Has Table booking  Has Online delivery  Is delivering now  Switch to order menu  Price range  Aggregate rating  Rating color  Rating text  Votes
# 53             Amber               1             New Delhi  N-19, Connaught Place, New Delhi                                     Connaught Place            Connaught Place, New Delhi            77.220891  28.630197  North Indian, Chinese, Mughlai            1800                  Indian Rupees(Rs.)  Yes                Yes                  No                 No                    3            2.6               Orange        Average      152      1
# ...

# %%
df['Restaurant ID'].value_counts()
# Out:
# 6317637     1
# 18254520    1
# 18462589    1
# 18336474    1
# 18336477    1
#            ..
# 313059      1
# 763         1
# 7557        1
# 525         1
# 5927402     1
# Name: Restaurant ID, Length: 9551, dtype: int64

# %%
df['Restaurant ID'].idxmax()
# Out:
# 1329

# %%
df['Currency'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9546    False
# 9547    False
# 9548    False
# 9549    False
# 9550    False
# Name: Currency, Length: 9551, dtype: bool

# %%
df['Currency'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 9551 entries, 0 to 9550
# Series name: Currency
# Non-Null Count  Dtype
# --------------  -----
# 9551 non-null   object
# dtypes: object(1)
# memory usage: 74.7+ KB

# %%
df['Restaurant ID'].argmax()
# Out:
# 1329

# %%
df.sort_values(by='Restaurant Name')
# Out:
#       Restaurant ID       Restaurant Name  Country Code             City  \
# 8947       18490967          Let's Burrrp             1            Noida
# 2459        3100446                   #45             1        Mangalore
# 9148       18378803          #Dilliwaala6             1       Puducherry
# 2613       18311951          #InstaFreeze             1        New Delhi
# 6998       18336489           #OFF Campus             1        New Delhi
# ...             ...                   ...           ...              ...
# 4659       18361747    t Lounge by Dilmah             1        New Delhi
# 9454        6401789                tashas           189        Cape Town
# 9334        7100938              wagamama           148  Wellington City
# 3120       18222559  {Niche} - Cafe & Bar             1        New Delhi
# 9523        6000871   íukuraÛôa SofrasÛ±           208           Ankara
#
#                                                 Address            Locality  \
# ...

# %%
df.sort_values(by='Restaurant Name',ascending=False)
# Out:
#       Restaurant ID       Restaurant Name  Country Code             City  \
# 9523        6000871   íukuraÛôa SofrasÛ±           208           Ankara
# 3120       18222559  {Niche} - Cafe & Bar             1        New Delhi
# 9334        7100938              wagamama           148  Wellington City
# 9454        6401789                tashas           189        Cape Town
# 4659       18361747    t Lounge by Dilmah             1        New Delhi
# ...             ...                   ...           ...              ...
# 6998       18336489           #OFF Campus             1        New Delhi
# 2613       18311951          #InstaFreeze             1        New Delhi
# 9148       18378803          #Dilliwaala6             1       Puducherry
# 2459        3100446                   #45             1        Mangalore
# 8947       18490967          Let's Burrrp             1            Noida
#
#                                                 Address            Locality  \
# ...

# %%
df.sort_values(by=['Restaurant ID','Restaurant Name'],
               ascending=False)
# Out:
#       Restaurant ID                Restaurant Name  Country Code       City  \
# 1329       18500652                Mahek By Greenz             1    Gurgaon
# 8773       18500639          Chandni Chowk 2 China             1      Noida
# 1762       18500628                   Grill & Cafe             1    Gurgaon
# 7679       18500618                    Veg. Darbar             1  New Delhi
# 7836       18499493                        Zombiez             1  New Delhi
# ...             ...                            ...           ...        ...
# 3801             65                Drums of Heaven             1  New Delhi
# 3746             64  Diva - The Italian Restaurant             1  New Delhi
# 3192             60               Colonel's Kababz             1  New Delhi
# 3016             55                        Berco's             1  New Delhi
# 2999             53                          Amber             1  New Delhi
#
# ...

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df.plot.bar(x='Restaurant Name',y='Restaurant ID')
# Out:
# <Axes: xlabel='Restaurant Name'>
# /usr/local/lib/python3.9/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 140 (\x8c) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.9/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 138 (\x8a) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.9/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 159 (\x9f) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.9/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 135 (\x87) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.9/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 157 (\x9d) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.9/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 134 (\x86) missing from current font.
#   func(*args, **kwargs)
# ...
